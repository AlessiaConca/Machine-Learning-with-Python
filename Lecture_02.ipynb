# %% [markdown]
# # Pandas

# %%
! pip install pandas --upgrade

# %%
import pandas as pd
pd.__version__ # restart the virtual environment first
# Out:
# '2.1.1'

# %% [markdown]
# # Create, read and write data

# %% [markdown]
# ## Creating data

# %%
df = pd.Series([100, 210, 320, 450], name="Sales", index=["2019 sales", "2020 sales", "2021 sales", "2022 sales"])
df
# Out:
# 210

# %%
df = pd.DataFrame({
    "2019 sales": [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200],
    "2020 sales": [110, 210, 310, 410, 510, 610, 710, 810, 910, 1010, 1110, 1210]
}, index=["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Ago", "Sep", "Oct", "Nov", "Dec"])
df
# Out:
#      2019 sales  2020 sales
# Jan         100         110
# Feb         200         210
# Mar         300         310
# Apr         400         410
# May         500         510
# Jun         600         610
# Jul         700         710
# Ago         800         810
# Sep         900         910
# Oct        1000        1010
# Nov        1100        1110
# Dec        1200        1210

# %%
df["2020 sales"].sum()
# Out:
# 7920

# %% [markdown]
# ## Reading and writing data

# %%
# reading
df = pd.read_csv("listings.csv")
df

# %%
# writing
df.to_csv("listings_cleaned.csv", index=False)

# %%
# number of rows and columns
df.shape
# Out:
# (48016, 18)

# %%
#df.head() # show the first 5 rows
df.tail(10) # show the last 10 rows

# %%
# get the column names
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %% [markdown]
# ## Indexing, selecting and assigning

# %% [markdown]
# ## Accesing columns

# %%
# Accessing a column (version 1)
df.room_type
# Out:
# 0        Entire home/apt
# 1        Entire home/apt
# 2           Private room
# 3        Entire home/apt
# 4        Entire home/apt
#               ...
# 48011    Entire home/apt
# 48012    Entire home/apt
# 48013    Entire home/apt
# 48014    Entire home/apt
# 48015       Private room
# Name: room_type, Length: 48016, dtype: object

# %%
# Accessing a column (version 2 -- preferred)
df["room_type"]
for c in ["neighbourhood_group", "neighbourhood"]:
    print(c, df[c].unique())

# %%
# Accessing two columns
df[["neighbourhood_group", "neighbourhood"]]
# Out:
#       neighbourhood_group         neighbourhood
# 0                   Lecce  Castrignano del Capo
# 1                    Bari                  Bari
# 2                   Lecce                Matino
# 3                   Lecce                Ugento
# 4                   Lecce             Poggiardo
# ...                   ...                   ...
# 48011               Lecce              Spongano
# 48012               Lecce                Ugento
# 48013               Lecce              Spongano
# 48014                Bari      Polignano a Mare
# 48015                Bari     Castellana Grotte
#
# [48016 rows x 2 columns]

# %%
df[[df.columns[4], df.columns[5]]]
# Out:
#       neighbourhood_group         neighbourhood
# 0                   Lecce  Castrignano del Capo
# 1                    Bari                  Bari
# 2                   Lecce                Matino
# 3                   Lecce                Ugento
# 4                   Lecce             Poggiardo
# ...                   ...                   ...
# 48011               Lecce              Spongano
# 48012               Lecce                Ugento
# 48013               Lecce              Spongano
# 48014                Bari      Polignano a Mare
# 48015                Bari     Castellana Grotte
#
# [48016 rows x 2 columns]

# %%
# access rows
df["room_type"][10:20]
# Out:
# 10    Entire home/apt
# 11    Entire home/apt
# 12    Entire home/apt
# 13    Entire home/apt
# 14    Entire home/apt
# 15    Entire home/apt
# 16    Entire home/apt
# 17    Entire home/apt
# 18    Entire home/apt
# 19    Entire home/apt
# Name: room_type, dtype: object

# %%
df[["room_type"]][10:20]
# Out:
#           room_type
# 10  Entire home/apt
# 11  Entire home/apt
# 12  Entire home/apt
# 13  Entire home/apt
# 14  Entire home/apt
# 15  Entire home/apt
# 16  Entire home/apt
# 17  Entire home/apt
# 18  Entire home/apt
# 19  Entire home/apt

# %%
# accesing row with index == 1
df.iloc[1]
# Out:
# id                                                              871797626686228714
# name                              Rental unit in Bari · 1 bedroom · 1 bed · 1 bath
# host_id                                                                  498102198
# host_name                                                                     Easy
# neighbourhood_group                                                           Bari
# neighbourhood                                                                 Bari
# latitude                                                                  41.12367
# longitude                                                                 16.85844
# room_type                                                          Entire home/apt
# price                                                                          107
# minimum_nights                                                                   1
# number_of_reviews                                                                0
# last_review                                                                    NaN
# reviews_per_month                                                              NaN
# calculated_host_listings_count                                                   5
# availability_365                                                                 7
# number_of_reviews_ltm                                                            0
# license                                                                        NaN
# Name: 1, dtype: object

# %%
df.iloc[10, 0]
# Out:
# 18130788

# %%
df.iloc[0:10, 0]
# Out:
# 0              20009845
# 1    871797626686228714
# 2    933977345613784276
# 3              21558875
# 4    924521740641122778
# 5              37529281
# 6    594069192085321405
# 7               3228329
# 8               7789194
# 9    932507624309365236
# Name: id, dtype: int64

# %%
df.iloc[3:10, 0:3]
# Out:
#                    id                                               name  \
# 3            21558875  Vacation home in Fontanelle · ★4.88 · 3 bedroo...
# 4  924521740641122778   Home in Poggiardo · 2 bedrooms · 2 beds · 1 bath
# 5            37529281  Bed and breakfast in San Vito dei Normanni · 1...
# 6  594069192085321405  Home in Porto Cesareo · ★4.33 · 4 bedrooms · 8...
# 7             3228329  Rental unit in Baia Verde · ★4.80 · 1 bedroom ...
# 8             7789194  Home in Porto Cesareo · ★4.75 · 2 bedrooms · 4...
# 9  932507624309365236  Bed and breakfast in Bari · ★4.71 · 1 bedroom ...
#
#      host_id
# 3  532530809
# 4   26794110
# 5     987289
# 6  108951352
# 7   16338830
# 8   28497898
# 9  263017793

# %%
df.iloc[[2,4,6], 0:3]
# Out:
#                    id                                               name  \
# 2  933977345613784276  Bed and breakfast in Matino · 2 bedrooms · 3 b...
# 4  924521740641122778   Home in Poggiardo · 2 bedrooms · 2 beds · 1 bath
# 6  594069192085321405  Home in Porto Cesareo · ★4.33 · 4 bedrooms · 8...
#
#      host_id
# 2   97364266
# 4   26794110
# 6  108951352

# %%
# if I use column names should use loc (not iloc)
df.loc[[2,4,6], "room_type"]
# Out:
# 2       Private room
# 4    Entire home/apt
# 6    Entire home/apt
# Name: room_type, dtype: object

# %%
df.loc[2:5, ["host_name", "room_type"]]
# Out:
#     host_name        room_type
# 2  MariaElena     Private room
# 3       Lucia  Entire home/apt
# 4  Buena Onda  Entire home/apt
# 5   Guglielmo     Private room

# %%
#df[["host_name", "room_type"]]
df.loc[:, ["host_name", "room_type"]]
# Out:
#                host_name        room_type
# 0                 Julien  Entire home/apt
# 1                   Easy  Entire home/apt
# 2             MariaElena     Private room
# 3                  Lucia  Entire home/apt
# 4             Buena Onda  Entire home/apt
# ...                  ...              ...
# 48011          Giancarlo  Entire home/apt
# 48012            Antonio  Entire home/apt
# 48013            Michela  Entire home/apt
# 48014  Jacqueline Renate  Entire home/apt
# 48015           Vincenzo     Private room
#
# [48016 rows x 2 columns]

# %% [markdown]
# ## Manipulating the index

# %%
df = df.set_index("host_name")
df
# Out:
#                                                                 name  \
# host_name
# Julien             Home in Provincia di Lecce · ★4.81 · 3 bedroom...
# Easy                Rental unit in Bari · 1 bedroom · 1 bed · 1 bath
# MariaElena         Bed and breakfast in Matino · 2 bedrooms · 3 b...
# Lucia              Vacation home in Fontanelle · ★4.88 · 3 bedroo...
# Buena Onda          Home in Poggiardo · 2 bedrooms · 2 beds · 1 bath
# ...                                                              ...
# Giancarlo          Villa in Spongano · 4 bedrooms · 9 beds · 3 baths
# Antonio            Home in Torre San Giovanni · 3 bedrooms · 6 be...
# Michela            Villa in Spongano · ★4.50 · 2 bedrooms · 4 bed...
# Jacqueline Renate  Condo in Polignano a Mare · ★4.83 · 2 bedrooms...
# Vincenzo           Bed and breakfast in Castellana Grotte · 1 bed...
#
#                      host_id neighbourhood_group         neighbourhood  \
# host_name
# Julien               3325119               Lecce  Castrignano del Capo
# Easy               498102198                Bari                  Bari
# MariaElena          97364266               Lecce                Matino
# Lucia              532530809               Lecce                Ugento
# Buena Onda          26794110               Lecce             Poggiardo
# ...                      ...                 ...                   ...
# Giancarlo           36358333               Lecce              Spongano
# Antonio             60480293               Lecce                Ugento
# Michela             23288546               Lecce              Spongano
# Jacqueline Renate    1318568                Bari      Polignano a Mare
# Vincenzo            12941913                Bari     Castellana Grotte
#
#                     latitude  longitude        room_type  price  \
# host_name
# Julien             39.812110  18.328000  Entire home/apt    115
# Easy               41.123670  16.858440  Entire home/apt    107
# MariaElena         40.029885  18.136070     Private room     60
# Lucia              39.869980  18.145130  Entire home/apt    170
# Buena Onda         40.046419  18.375289  Entire home/apt     55
# ...                      ...        ...              ...    ...
# Giancarlo          40.014210  18.365380  Entire home/apt    220
# Antonio            39.895480  18.104870  Entire home/apt     64
# Michela            40.007450  18.345540  Entire home/apt     90
# Jacqueline Renate  40.994730  17.225500  Entire home/apt     73
# Vincenzo           40.827660  17.209120     Private room     70
#
#                    minimum_nights  number_of_reviews last_review  \
# host_name
# Julien                          3                 16  2023-09-10
# Easy                            1                  0         NaN
# MariaElena                      2                  0         NaN
# Lucia                           5                  8  2023-08-19
# Buena Onda                      1                  2  2023-09-15
# ...                           ...                ...         ...
# Giancarlo                       1                  2  2022-08-09
# Antonio                         1                  0         NaN
# Michela                         2                  4  2023-08-06
# Jacqueline Renate               3                 23  2023-09-07
# Vincenzo                        1                  0         NaN
#
#                    reviews_per_month  calculated_host_listings_count  \
# host_name
# Julien                          0.21                               8
# Easy                             NaN                               5
# MariaElena                       NaN                              24
# Lucia                           0.16                               1
# Buena Onda                      1.25                             124
# ...                              ...                             ...
# Giancarlo                       0.04                               1
# Antonio                          NaN                              61
# Michela                         0.28                               1
# Jacqueline Renate               0.90                               5
# Vincenzo                         NaN                               7
#
#                    availability_365  number_of_reviews_ltm  \
# host_name
# Julien                           25                      3
# Easy                              7                      0
# MariaElena                      364                      0
# Lucia                           263                      3
# Buena Onda                      176                      2
# ...                             ...                    ...
# Giancarlo                       329                      0
# Antonio                          24                      0
# Michela                         177                      1
# Jacqueline Renate               365                      9
# Vincenzo                        362                      0
#
#                                license
# host_name
# Julien                             NaN
# Easy                               NaN
# MariaElena                         NaN
# Lucia                              NaN
# Buena Onda         LE07506191000035453
# ...                                ...
# Giancarlo                          NaN
# Antonio            LE07509091000033340
# Michela            LE07507891000033141
# Jacqueline Renate                  NaN
# Vincenzo                           NaN
#
# [48016 rows x 16 columns]

# %%
df.loc["Buena Onda", "name"]
# Out:
# host_name
# Buena Onda     Home in Poggiardo · 2 bedrooms · 2 beds · 1 bath
# Buena Onda    Villa in Torre Suda · 3 bedrooms · 3 beds · 3 ...
# Buena Onda    Home in Torre Suda · 2 bedrooms · 3 beds · 1 bath
# Buena Onda    Villa in Castro · ★4.86 · 2 bedrooms · 5 beds ...
# Buena Onda    Home in Baia Verde · 2 bedrooms · 4 beds · 1 bath
#                                     ...
# Buena Onda          Home in Nardò · 1 bedroom · 3 beds · 1 bath
# Buena Onda          Home in Nardò · 1 bedroom · 3 beds · 1 bath
# Buena Onda    Villa in Carovigno · ★5.0 · 3 bedrooms · 6 bed...
# Buena Onda    Rental unit in Cutrofiano · 5 bedrooms · 5 bed...
# Buena Onda    Home in Torre Suda · 3 bedrooms · 5 beds · 2 b...
# Name: name, Length: 326, dtype: object

# %% [markdown]
# # Conditional selection

# %%
df["neighbourhood_group"] == "Bari"
# Out:
# host_name
# Julien               False
# Easy                  True
# MariaElena           False
# Lucia                False
# Buena Onda           False
#                      ...
# Giancarlo            False
# Antonio              False
# Michela              False
# Jacqueline Renate     True
# Vincenzo              True
# Name: neighbourhood_group, Length: 48016, dtype: bool

# %%
df.loc[df["neighbourhood_group"] == "Bari"]
# Out:
#                                                                 name  \
# host_name
# Easy                Rental unit in Bari · 1 bedroom · 1 bed · 1 bath
# Bari               Bed and breakfast in Bari · ★4.71 · 1 bedroom ...
# Cconforthotels     Vacation home in Bari · ★5.0 · 1 bedroom · 4 b...
# Rosa Anna          Villa in Putignano · ★5.0 · 3 bedrooms · 3 bed...
# Cconforthotels     Vacation home in Bari · 1 bedroom · 1 bed · 1 ...
# ...                                                              ...
# WePuglia Srl       trullo in Castellana Grotte · 1 bedroom · 1 be...
# Aldo               Condo in Polignano A Mare · ★4.83 · 1 bedroom ...
# Antonio            Home in Polignano a Mare · ★4.94 · 1 bedroom ·...
# Jacqueline Renate  Condo in Polignano a Mare · ★4.83 · 2 bedrooms...
# Vincenzo           Bed and breakfast in Castellana Grotte · 1 bed...
#
#                      host_id neighbourhood_group      neighbourhood  \
# host_name
# Easy               498102198                Bari               Bari
# Bari               263017793                Bari               Bari
# Cconforthotels        864615                Bari               Bari
# Rosa Anna           32677222                Bari          Putignano
# Cconforthotels        864615                Bari               Bari
# ...                      ...                 ...                ...
# WePuglia Srl       241678828                Bari   Polignano a Mare
# Aldo                32554926                Bari   Polignano a Mare
# Antonio            414644885                Bari   Polignano a Mare
# Jacqueline Renate    1318568                Bari   Polignano a Mare
# Vincenzo            12941913                Bari  Castellana Grotte
#
#                     latitude  longitude        room_type  price  \
# host_name
# Easy               41.123670  16.858440  Entire home/apt    107
# Bari               41.122082  16.873199     Private room     78
# Cconforthotels     41.118870  16.873040     Private room     95
# Rosa Anna          40.857040  17.142770  Entire home/apt    110
# Cconforthotels     41.121580  16.872220     Private room    119
# ...                      ...        ...              ...    ...
# WePuglia Srl       40.910892  17.162709  Entire home/apt    162
# Aldo               40.994880  17.226180  Entire home/apt     69
# Antonio            40.995670  17.224200  Entire home/apt     90
# Jacqueline Renate  40.994730  17.225500  Entire home/apt     73
# Vincenzo           40.827660  17.209120     Private room     70
#
#                    minimum_nights  number_of_reviews last_review  \
# host_name
# Easy                            1                  0         NaN
# Bari                            1                  7  2023-08-28
# Cconforthotels                  1                  3  2022-08-05
# Rosa Anna                       2                  5  2022-09-23
# Cconforthotels                  1                  1  2023-06-25
# ...                           ...                ...         ...
# WePuglia Srl                    3                  0         NaN
# Aldo                            1                 24  2023-09-09
# Antonio                         1                 48  2023-09-22
# Jacqueline Renate               3                 23  2023-09-07
# Vincenzo                        1                  0         NaN
#
#                    reviews_per_month  calculated_host_listings_count  \
# host_name
# Easy                             NaN                               5
# Bari                            3.13                              45
# Cconforthotels                  0.20                              42
# Rosa Anna                       0.08                               1
# Cconforthotels                  0.32                              42
# ...                              ...                             ...
# WePuglia Srl                     NaN                              26
# Aldo                            0.31                               2
# Antonio                         1.83                               1
# Jacqueline Renate               0.90                               5
# Vincenzo                         NaN                               7
#
#                    availability_365  number_of_reviews_ltm  \
# host_name
# Easy                              7                      0
# Bari                             89                      7
# Cconforthotels                  310                      0
# Rosa Anna                        18                      0
# Cconforthotels                  347                      1
# ...                             ...                    ...
# WePuglia Srl                      0                      0
# Aldo                             77                      5
# Antonio                         267                     16
# Jacqueline Renate               365                      9
# Vincenzo                        362                      0
#
#                                license
# host_name
# Easy                               NaN
# Bari                               NaN
# Cconforthotels                     NaN
# Rosa Anna                          NaN
# Cconforthotels                     NaN
# ...                                ...
# WePuglia Srl                       NaN
# Aldo                               NaN
# Antonio            BA07203591000020554
# Jacqueline Renate                  NaN
# Vincenzo                           NaN
#
# [8737 rows x 16 columns]

# %%
df.loc[df["neighbourhood_group"] == "Bari", ["latitude", "longitude"]]
# Out:
#                     latitude  longitude
# host_name
# Easy               41.123670  16.858440
# Bari               41.122082  16.873199
# Cconforthotels     41.118870  16.873040
# Rosa Anna          40.857040  17.142770
# Cconforthotels     41.121580  16.872220
# ...                      ...        ...
# WePuglia Srl       40.910892  17.162709
# Aldo               40.994880  17.226180
# Antonio            40.995670  17.224200
# Jacqueline Renate  40.994730  17.225500
# Vincenzo           40.827660  17.209120
#
# [8737 rows x 2 columns]

# %%
# Exercise: Get the number of listings in neighbourhood_group "Taranto"
# version 1 (mr Manetta) len(df.loc[df["neighbourhood_group"] == "Taranto"])
df.loc[df["neighbourhood_group"] == "Taranto"].shape[0]
# Out:
# 4340

# %%
# Exercise: list all the private rooms in Taranto
# Tip: A and B --> (A) & (B)
df.loc[(df["neighbourhood_group"] == "Taranto") & (df["room_type"] == "Private room")]
# Out:
#                                                           name    host_id  \
# host_name
# Vito         Villa in Castellaneta Marina · 1 bedroom · 2 b...   80971292
# Agnese       Bed and breakfast in Mottola · 1 bedroom · 2 b...   20148270
# Antonio      Bed and breakfast in Grottaglie · ★4.86 · 1 be...  101098515
# Domenico     Bed and breakfast in Marina di Ginosa · ★5.0 ·...   16600594
# Andrea       Home in San Pietro In Bevagna · 5 bedrooms · 7...   75224706
# ...                                                        ...        ...
# Raro Realty  Resort in Taranto · ★New · 1 bedroom · 1 bed ·...   93984333
# Alinella     Condo in Taranto · ★4.98 · 1 bedroom · 1 bed ·...  264079445
# Filomena     Bed and breakfast in Taranto · ★4.86 · 1 bedro...  148637178
# Simona       Home in Taranto · 1 bedroom · 1 bed · 1 privat...   55587111
# Vincenzo     Serviced apartment in Taranto · 1 bedroom · 3 ...   89106462
#
#             neighbourhood_group neighbourhood  latitude  longitude  \
# host_name
# Vito                    Taranto  Castellaneta  40.47726  16.932220
# Agnese                  Taranto       Mottola  40.64440  17.077450
# Antonio                 Taranto    Grottaglie  40.53505  17.430340
# Domenico                Taranto        Ginosa  40.42298  16.881770
# Andrea                  Taranto      Manduria  40.30600  17.645510
# ...                         ...           ...       ...        ...
# Raro Realty             Taranto       Taranto  40.35467  17.426737
# Alinella                Taranto       Taranto  40.47406  17.233640
# Filomena                Taranto       Taranto  40.41253  17.219400
# Simona                  Taranto       Taranto  40.42379  17.232570
# Vincenzo                Taranto       Taranto  40.42273  17.234390
#
#                 room_type  price  minimum_nights  number_of_reviews  \
# host_name
# Vito         Private room    129               2                  0
# Agnese       Private room    100               3                  2
# Antonio      Private room     62               1                  7
# Domenico     Private room     74               1                 10
# Andrea       Private room    200               7                  1
# ...                   ...    ...             ...                ...
# Raro Realty  Private room    363               1                  0
# Alinella     Private room     81               2                 45
# Filomena     Private room     43               1                  7
# Simona       Private room     40               2                  1
# Vincenzo     Private room     70               3                  0
#
#             last_review  reviews_per_month  calculated_host_listings_count  \
# host_name
# Vito                NaN                NaN                               2
# Agnese       2018-08-11               0.03                               1
# Antonio      2022-07-16               0.11                               1
# Domenico     2023-05-24               0.15                               4
# Andrea       2018-04-28               0.02                               1
# ...                 ...                ...                             ...
# Raro Realty         NaN                NaN                              76
# Alinella     2023-07-22               0.86                               2
# Filomena     2022-09-22               0.13                               2
# Simona       2021-07-21               0.04                               5
# Vincenzo            NaN                NaN                               2
#
#              availability_365  number_of_reviews_ltm  \
# host_name
# Vito                        0                      0
# Agnese                    364                      0
# Antonio                    62                      0
# Domenico                   31                      3
# Andrea                    365                      0
# ...                       ...                    ...
# Raro Realty               364                      0
# Alinella                   83                      7
# Filomena                    1                      0
# Simona                    365                      0
# Vincenzo                  359                      0
#
#                                   license
# host_name
# Vito                                  NaN
# Agnese                                NaN
# Antonio      (C.I.S.) TA07300861000016011
# Domenico                              NaN
# Andrea                                NaN
# ...                                   ...
# Raro Realty                           NaN
# Alinella                              NaN
# Filomena                              NaN
# Simona                                NaN
# Vincenzo                              NaN
#
# [675 rows x 16 columns]

# %%
# Exercise: list all the row in Taranto or Foggia
# Tip: A or B --> (A) | (B)
df.loc[(df["neighbourhood_group"] == "Foggia") | (df["neighbourhood_group"] == "Taranto")]

# %%
# Exercise: how many rooms with price lower than 300 euros are in the database?
df.loc[df["price"] < 300].shape[0]
# Out:
# 44918

# %%
# another way
df.query("neighbourhood_group == 'Taranto' or neighbourhood_group == 'Foggia'")
df.query("price < 300").shape[0]

# %%
# NaN values
#df["last_review"].isna()
#df["last_review"].notna()

df[df["last_review"].notna()]

# %% [markdown]
# # Assign values

# %%
# df["price"] = 1000
df.loc[:, "price"] = 1000
df

# %%
df.loc[:, "number_of_reviews"] = df.loc[:, "number_of_reviews"] + 10
df.loc[:, "number_of_reviews"]
# Out:
# host_name
# Julien               26
# Easy                 10
# MariaElena           10
# Lucia                18
# Buena Onda           12
#                      ..
# Giancarlo            12
# Antonio              10
# Michela              14
# Jacqueline Renate    33
# Vincenzo             10
# Name: number_of_reviews, Length: 48016, dtype: int64

# %%
# neighbourhood_group:Bari --> Lecce
df.loc[df["neighbourhood_group"] == "Bari"] = "Lecce"
df

# %%
f = df["neighbourhood_group"] == "Lecce"
df.loc[f, "price"] =  df.loc[f, "price"] + 10
df

# %% [markdown]
# # Summary functions and mapping

# %% [markdown]
# ## Summary functions

# %%
df["price"].mean()
# Out:
# 147.8835388203932

# %%
df["price"].max()
# Out:
# 90000

# %%
df["price"].min()
# Out:
# 9

# %%
df["price"].std()
# Out:
# 904.427767879358

# %%
df["price"].describe()
# Out:
# count    48016.000000
# mean       147.883539
# std        904.427768
# min          9.000000
# 25%         60.000000
# 50%         86.000000
# 75%        130.000000
# max      90000.000000
# Name: price, dtype: float64

# %%
df["room_type"].describe()
# Out:
# count               48016
# unique                  4
# top       Entire home/apt
# freq                39592
# Name: room_type, dtype: object

# %%
df["room_type"].unique()
# Out:
# array(['Entire home/apt', 'Private room', 'Hotel room', 'Shared room'],
#       dtype=object)

# %%
df["room_type"].value_counts()
# Out:
# room_type
# Entire home/apt    39592
# Private room        8013
# Hotel room           343
# Shared room           68
# Name: count, dtype: int64

# %%
for c in df.columns:
    print(c, df[c].isna().sum())
# Out:
# id 0
# name 0
# host_id 0
# host_name 0
# neighbourhood_group 0
# neighbourhood 0
# latitude 0
# longitude 0
# room_type 0
# price 0
# minimum_nights 0
# number_of_reviews 0
# last_review 16318
# reviews_per_month 16318
# calculated_host_listings_count 0
# availability_365 0
# number_of_reviews_ltm 0
# license 36191

# %%
df[["price", "minimum_nights"]].mean()
# Out:
# price             147.883539
# minimum_nights      3.295818
# dtype: float64

# %%
df.loc[df["neighbourhood_group"] == "Bari", "price"].mean()
# Out:
# 134.4257754377933

# %% [markdown]
# ## Mapping

# %%
df["room_type"].unique()
# Out:
# array(['Entire home/apt', 'Private room', 'Hotel room', 'Shared room'],
#       dtype=object)

# %%
m = {
    'Entire home/apt': "E",
    'Private room': "P",
    'Hotel room': "H",
    'Shared room': "S"
}
df["room_type"].map(m)

# %%
# def f(x):
#     return len(str(x))

# lambda x: len(str(x))

df["room_type"].map(lambda x: len(str(x)))
# Out:
# 0        15
# 1        15
# 2        12
# 3        15
# 4        15
#          ..
# 48011    15
# 48012    15
# 48013    15
# 48014    15
# 48015    12
# Name: room_type, Length: 48016, dtype: int64

# %%
# %%time
price_mean = df["price"].mean()

def distance_from_the_mean(row):
    return row["price"] - price_mean

df[["price"]].apply(distance_from_the_mean, axis="columns")

# do NOT do this
# for row in df.index:
#     df.loc[row, "price"] = df.loc[row, "price"] - price_mean

# %% [markdown]
# # Data types and missing values

# %%
# reading
df = pd.read_csv("listings.csv")
df

# %% [markdown]
# ## Data types

# %%
df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# license                            object
# dtype: object

# %%
df["price"].dtype
# Out:
# dtype('int64')

# %%
df["price"].astype('int32')
# Out:
# 0        115
# 1        107
# 2         60
# 3        170
# 4         55
#         ...
# 48011    220
# 48012     64
# 48013     90
# 48014     73
# 48015     70
# Name: price, Length: 48016, dtype: int32

# %%
# putting the dtype in read_csv
df = pd.read_csv("listings.csv", dtype={"price": "int32", "minimum_nights": "uint16"})
df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int32
# minimum_nights                     uint16
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# license                            object
# dtype: object

# %% [markdown]
# ## Missing values

# %%
# df[df["reviews_per_month"].isna(), "reviews_per_month"] = 0
df["reviews_per_month"].fillna(0).astype("int16")

df["reviews_per_month"].fillna(df["reviews_per_month"].mean())
# Out:
# 0        0.21000
# 1        0.61673
# 2        0.61673
# 3        0.16000
# 4        1.25000
#           ...
# 48011    0.04000
# 48012    0.61673
# 48013    0.28000
# 48014    0.90000
# 48015    0.61673
# Name: reviews_per_month, Length: 48016, dtype: float64

# %% [markdown]
# # Exercises

# %%
df = pd.read_csv("listings.csv")
df.head()

# %%
# Rise the prices of Hotel rooms in Bari by 12%
# def plus_12_percent(row):
#     return row["price"] * 1.12

# df[["price"]].apply(plus_12_percent, axis="columns")

f = (df["neighbourhood_group"] == "Bari") & (df["room_type"] == "Hotel room")
df.loc[f, "price"] =  df.loc[f, "price"] * 1.12
# Out:
# 0        128.80
# 1        119.84
# 2         67.20
# 3        190.40
# 4         61.60
#           ...
# 48011    246.40
# 48012     71.68
# 48013    100.80
# 48014     81.76
# 48015     78.40
# Length: 48016, dtype: float64

# %%
# How many "Entire home/apt" are "Bed and breakfast"?
# tip: use df["field"].str.contains('X')

df[(df["room_type"] == 'Entire home/apt') & df["name"].str.contains("Bed and breakfast")].shape[0]
# Out:
# 39

# %%
# Mean price by zone (N, S, C) taking
#   Foggia --> N
#   Bari, Barletta-Andria-Trani --> C
#   Lecce, Brindisi, Taranto --> S

# f_N = df["neighbourhood_group"] == "Foggia"
# df.loc[f_N, "price"].mean()

# f_C = (df["neighbourhood_group"] == "Bari") | (df["neighbourhood_group"] == "Barletta-Andria-Trani")
# df.loc[f_C, "price"].mean()

# f_S = (df["neighbourhood_group"] == "Lecce") | (df["neighbourhood_group"] == "Brindisi") | (df["neighbourhood_group"] == "Taranto")
# df.loc[f_S, "price"].mean()


# m = {
#     "Foggia": "N",
#     "Bari": "C", "Barletta-Andria-Trani": "C",
#     "Lecce": "S", "Brindisi": "S", "Taranto" : "S"
# }

#df["neighbourhood_group"] = df["neighbourhood_group"].map(m)

df.groupby("neighbourhood_group").price.mean()
# Out:
# neighbourhood_group
# C    129.513684
# N    119.635140
# S    155.426076
# Name: price, dtype: float64
